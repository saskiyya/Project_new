# %%
import pandas as pd
df = pd.read_csv("dataset_gaji_data_science.csv")
df
# Out:
#       Tahun Kerja Tingkat Pengalaman Jenis Pekerjaan  \
# 0            2023             Senior           Tetap
# 1            2023           Menengah         Kontrak
# 2            2023           Menengah         Kontrak
# 3            2023             Senior           Tetap
# 4            2023             Senior           Tetap
# ...           ...                ...             ...
# 3750         2020             Senior           Tetap
# 3751         2021           Menengah           Tetap
# 3752         2020             Pemula           Tetap
# 3753         2020             Pemula         Kontrak
# 3754         2021             Senior           Tetap
#
#                        Jabatan     Gaji Mata Uang  Gaji (USD) Negara Tinggal  \
# 0     Principal Data Scientist    80000       EUR       85847             ES
# 1                  ML Engineer    30000       USD       30000             US
# 2                  ML Engineer    25500       USD       25500             US
# 3               Data Scientist   175000       USD      175000             CA
# 4               Data Scientist   120000       USD      120000             CA
# ...                        ...      ...       ...         ...            ...
# 3750            Data Scientist   412000       USD      412000             US
# 3751  Principal Data Scientist   151000       USD      151000             US
# 3752            Data Scientist   105000       USD      105000             US
# 3753     Business Data Analyst   100000       USD      100000             US
# 3754      Data Science Manager  7000000       INR       94665             IN
#
#      Sistem Kerja Lokasi Perusahaan Ukuran Perusahaan
# 0          Remote                ES             Besar
# 1          Remote                US             Kecil
# 2          Remote                US             Kecil
# 3          Remote                CA          Menengah
# 4          Remote                CA          Menengah
# ...           ...               ...               ...
# 3750       Remote                US             Besar
# 3751       Remote                US             Besar
# 3752       Remote                US             Kecil
# 3753       Remote                US             Besar
# 3754       Hybrid                IN             Besar
#
# [3755 rows x 11 columns]

# %%
df.shape
# Out:
# (3755, 11)

# %%
df.columns
# Out:
# Index(['Tahun Kerja', 'Tingkat Pengalaman', 'Jenis Pekerjaan', 'Jabatan',
#        'Gaji', 'Mata Uang', 'Gaji (USD)', 'Negara Tinggal', 'Sistem Kerja',
#        'Lokasi Perusahaan', 'Ukuran Perusahaan'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Tahun Kerja            int64
# Tingkat Pengalaman    object
# Jenis Pekerjaan       object
# Jabatan               object
# Gaji                   int64
# Mata Uang             object
# Gaji (USD)             int64
# Negara Tinggal        object
# Sistem Kerja          object
# Lokasi Perusahaan     object
# Ukuran Perusahaan     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Tahun Kerja         3755 non-null   int64
#  1   Tingkat Pengalaman  3755 non-null   object
#  2   Jenis Pekerjaan     3755 non-null   object
#  3   Jabatan             3755 non-null   object
#  4   Gaji                3755 non-null   int64
#  5   Mata Uang           3755 non-null   object
#  6   Gaji (USD)          3755 non-null   int64
#  7   Negara Tinggal      3755 non-null   object
#  8   Sistem Kerja        3755 non-null   object
#  9   Lokasi Perusahaan   3755 non-null   object
#  10  Ukuran Perusahaan   3755 non-null   object
# dtypes: int64(3), object(8)
# memory usage: 322.8+ KB

# %%
df.describe()
# Out:
#        Tahun Kerja          Gaji     Gaji (USD)
# count  3755.000000  3.755000e+03    3755.000000
# mean   2022.373635  1.906956e+05  137570.389880
# std       0.691448  6.716765e+05   63055.625278
# min    2020.000000  6.000000e+03    5132.000000
# 25%    2022.000000  1.000000e+05   95000.000000
# 50%    2022.000000  1.380000e+05  135000.000000
# 75%    2023.000000  1.800000e+05  175000.000000
# max    2023.000000  3.040000e+07  450000.000000

# %%
df.head()
# Out:
#    Tahun Kerja Tingkat Pengalaman Jenis Pekerjaan                   Jabatan  \
# 0         2023             Senior           Tetap  Principal Data Scientist
# 1         2023           Menengah         Kontrak               ML Engineer
# 2         2023           Menengah         Kontrak               ML Engineer
# 3         2023             Senior           Tetap            Data Scientist
# 4         2023             Senior           Tetap            Data Scientist
#
#      Gaji Mata Uang  Gaji (USD) Negara Tinggal Sistem Kerja Lokasi Perusahaan  \
# 0   80000       EUR       85847             ES       Remote                ES
# 1   30000       USD       30000             US       Remote                US
# 2   25500       USD       25500             US       Remote                US
# 3  175000       USD      175000             CA       Remote                CA
# 4  120000       USD      120000             CA       Remote                CA
#
#   Ukuran Perusahaan
# 0             Besar
# 1             Kecil
# 2             Kecil
# 3          Menengah
# 4          Menengah

# %%
df.tail()
# Out:
#       Tahun Kerja Tingkat Pengalaman Jenis Pekerjaan  \
# 3750         2020             Senior           Tetap
# 3751         2021           Menengah           Tetap
# 3752         2020             Pemula           Tetap
# 3753         2020             Pemula         Kontrak
# 3754         2021             Senior           Tetap
#
#                        Jabatan     Gaji Mata Uang  Gaji (USD) Negara Tinggal  \
# 3750            Data Scientist   412000       USD      412000             US
# 3751  Principal Data Scientist   151000       USD      151000             US
# 3752            Data Scientist   105000       USD      105000             US
# 3753     Business Data Analyst   100000       USD      100000             US
# 3754      Data Science Manager  7000000       INR       94665             IN
#
#      Sistem Kerja Lokasi Perusahaan Ukuran Perusahaan
# 3750       Remote                US             Besar
# 3751       Remote                US             Besar
# 3752       Remote                US             Kecil
# 3753       Remote                US             Besar
# 3754       Hybrid                IN             Besar

# %%
df.sample()
# Out:
#       Tahun Kerja Tingkat Pengalaman Jenis Pekerjaan               Jabatan  \
# 1040         2023             Senior           Tetap  Data Quality Analyst
#
#        Gaji Mata Uang  Gaji (USD) Negara Tinggal Sistem Kerja  \
# 1040  72200       USD       72200             US       Kantor
#
#      Lokasi Perusahaan Ukuran Perusahaan
# 1040                US          Menengah

# %%
df.isna().sum()
# Out:
# Tahun Kerja           0
# Tingkat Pengalaman    0
# Jenis Pekerjaan       0
# Jabatan               0
# Gaji                  0
# Mata Uang             0
# Gaji (USD)            0
# Negara Tinggal        0
# Sistem Kerja          0
# Lokasi Perusahaan     0
# Ukuran Perusahaan     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1171)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df["Tingkat Pengalaman"], kde=True, color="Purple")
plt.title("Tingkat Pengalaman")
plt.show()

# %%
sns.histplot(df["Gaji (USD)"], kde=True, color="green")
plt.title("Gaji (USD)")
plt.show()

# %%
sns.histplot(df["Jenis Pekerjaan"], kde=True, color="Blue")
plt.title("Jenis Pekerjaan")
plt.show()

# %%
sns.histplot(df["Sistem Kerja"], kde=True, color="Red")
plt.title("Sistem Kerja")
plt.show()

# %%
sns.histplot(df["Ukuran Perusahaan"], kde=True, color="Brown")
plt.title("Ukuran Perusahaan")
plt.show()

# %%
num_features = ['Tahun Kerja', 'Gaji (USD)']

plt.figure(figsize=(5,4))
sns.heatmap(df[num_features].corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

X = df[["Tahun Kerja", "Tingkat Pengalaman", "Jenis Pekerjaan", "Sistem Kerja"]]
y = df["Gaji (USD)"]

numerical = ["Tahun Kerja"]
categorical = ["Tingkat Pengalaman", "Jenis Pekerjaan", "Sistem Kerja"]

preprocessor = ColumnTransformer([
    ("num", StandardScaler(), numerical),
    ("cat", OneHotEncoder(handle_unknown="ignore"), categorical)
])

model_linear = Pipeline([
    ("preprocessor", preprocessor),
    ("regressor", RandomForestRegressor())
])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model_linear.fit(X_train, y_train)
y_pred = model_linear.predict(X_test)

print("Linear Regression")
print("R2 :", r2_score(y_test, y_pred))
print("MAE :", mean_absolute_error(y_test, y_pred))
print("MSE :", mean_squared_error(y_test, y_pred))
# Out:
# Linear Regression
# R2 : 0.2577930453950631
# MAE : 42429.72209810788
# MSE : 2944481007.7189813

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

X = df[["Tahun Kerja", "Tingkat Pengalaman", "Jenis Pekerjaan", "Sistem Kerja"]]
y = df["Gaji (USD)"]

numerical = ["Tahun Kerja"]
categorical = ["Tingkat Pengalaman", "Jenis Pekerjaan", "Sistem Kerja"]

preprocessor = ColumnTransformer([
    ("num", StandardScaler(), numerical),
    ("cat", OneHotEncoder(handle_unknown="ignore"), categorical)
])

model_random = Pipeline([
    ("preprocessor", preprocessor),
    ("regressor", RandomForestRegressor())
])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model_random.fit(X_train, y_train)
y_pred = model_random.predict(X_test)

print("Random Forest Regressor")
print("R2 :", r2_score(y_test, y_pred))
print("MAE :", mean_absolute_error(y_test, y_pred))
print("MSE :", mean_squared_error(y_test, y_pred))
# Out:
# Random Forest Regressor
# R2 : 0.19537309417523685
# MAE : 42610.842523567124
# MSE : 3295865924.626245

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

X = df[["Tahun Kerja", "Tingkat Pengalaman", "Jenis Pekerjaan", "Sistem Kerja"]]
y = df["Gaji (USD)"]

numerical = ["Tahun Kerja"]
categorical = ["Tingkat Pengalaman", "Jenis Pekerjaan", "Sistem Kerja"]

preprocessor = ColumnTransformer([
    ("num", StandardScaler(), numerical),
    ("cat", OneHotEncoder(handle_unknown="ignore"), categorical)
])

model_tree = Pipeline([
    ("preprocessor", preprocessor),
    ("regressor", RandomForestRegressor())
])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model_tree.fit(X_train, y_train)
y_pred = model_tree.predict(X_test)

print("Decision Tree Regressor")
print("R2 :", r2_score(y_test, y_pred))
print("MAE :", mean_absolute_error(y_test, y_pred))
print("MSE :", mean_squared_error(y_test, y_pred))
# Out:
# Decision Tree Regressor
# R2 : 0.26131712738067625
# MAE : 42728.591946322296
# MSE : 2980953994.0858297

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(model_linear, X_train, y_train, cv=5, scoring="r2")

print("Scores : ", scores)
print("Scores Mean : ", scores.mean())
# Out:
# Scores :  [0.17559671 0.24049037 0.21344383 0.21711556 0.16171979]
# Scores Mean :  0.20167325072239534

# %%
import joblib

joblib.dump(model_linear, "model_gaji.joblib")
# Out:
# ['model_gaji.joblib']

# %%
import pandas as pd
import joblib

model_linear = joblib.load("model_gaji.joblib")

data_baru = pd.DataFrame([[
    "Senior",
    "Full-time",
    "Data Scientist",
    "Remote",
    "Besar",
    2023
]], columns=[
    "Tingkat Pengalaman",
    "Jenis Pekerjaan",
    "Jabatan",
    "Sistem Kerja",
    "Ukuran Perusahaan",
    "Tahun Kerja"
])

prediksi = model_linear.predict(data_baru)[0]
print(f"Model memprediksi jumlah gaji data Science (USD): {prediksi:.0f}")
# Out:
# Model memprediksi jumlah gaji data Science (USD): 155135
